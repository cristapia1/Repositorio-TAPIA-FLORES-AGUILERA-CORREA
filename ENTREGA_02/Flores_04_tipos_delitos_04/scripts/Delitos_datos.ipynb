# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns # importar la libreria seaborn

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/lalalalafinal.csv', encoding = 'latin_1',on_bad_lines='skip', sep=';')

# %%
df = df.astype(str)

# %%
df = df.apply(lambda x: x.str.replace('.0',''))

# %%
df = df.apply(lambda x: x.str.replace('nan',''))

# %%
df=df[1::]

# %%
df = df.rename(columns={'Unnamed: 0' : 'Grupo delictual'})

# %%
df[["2018","2019","2020","2021","2022","2023"]] = df[["2018","2019","2020","2021","2022","2023"]].astype(int)

# %%
df
# Out:
#                                Grupo delictual    2018    2019    2020  \
# 1          Delitos de mayor connotacion social  200188  205305  139617
# 2                                   Homicidios     227     258     360
# 3                                       Hurtos   55620   54264   24765
# 4                               Lesiones leves   17002   17939   12541
# 5   Lesiones menos graves, graves o gravisimas    4205    4778    3959
# 6                       Otros robos con fuerza    2829    2996    2222
# 7            Robo con violencia o intimidacion   40485   45380   39301
# 8          Robo de objetos de o desde vehiculo   27112   26842   19232
# 9                 Robo de vehi­culo motorizado   10810   10707   10060
# 10                      Robo en lugar habitado   12207   10912    6273
# 11                   Robo en lugar no habitado   11831   13797    9182
# 12                           Robo por sorpresa   16740   16174   10767
# ...

# %%
df.to_csv('/content/drive/My Drive/Delitos_datos.csv', index=False)
